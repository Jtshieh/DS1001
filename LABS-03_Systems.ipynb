# %% [markdown]
# <a href="https://colab.research.google.com/github/Jtshieh/DS1001/blob/main/LABS-03_Systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LABS-3: Systems Project
#
# In this notebook you will run a few cells to ensure that your environment is properly set up.

# %%
## First cell
# run this for step 11 in your instructions

print("Hello, World!")
# Out:
# Hello, World!

# %%
## Second cell
# run this for step 14 in your instructions

import pandas as pd

# %%
## Part 3: Accessing your data
# edit this code to load your data into your workspace

data = pd.read_csv('/content/sample_data/california_housing_train.csv') #add your data file path to this line!
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1010597297.py in <cell line: 0>()
#       2 # edit this code to load your data into your workspace
#       3
# ----> 4 data = pd.read_csv() #add your data file path to this line!
#       5 data.head()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'
